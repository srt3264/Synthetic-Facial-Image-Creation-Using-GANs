# %%
# !git clone https://github.com/NVlabs/stylegan2-ada-pytorch.git
# Out:
# Cloning into 'stylegan2-ada-pytorch'...
# remote: Enumerating objects: 128, done.
# remote: Total 128 (delta 0), reused 0 (delta 0), pack-reused 128
# Receiving objects: 100% (128/128), 1.12 MiB | 25.51 MiB/s, done.
# Resolving deltas: 100% (57/57), done.

# %%
# %cd /content/stylegan2-ada-pytorch
# Out:
# /content/stylegan2-ada-pytorch

# %%
# %ls
# Out:
# calc_metrics.py*  Dockerfile*     legacy.py*     __pycache__/      training/
# covert_to.py      docker_run.sh*  LICENSE.txt*   README.md*        train.py*
# dataset_tool.py*  docs/           metrics/       style_mixing.py*
# dnnlib/           generate.py*    projector.py*  torch_utils/

# %%
# %pip install torch==1.7.1+cu110 torchvision==0.8.2+cu110 -f https://download.pytorch.org/whl/torch_stable.html
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 GB 1.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 95.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: torch
#     Found existing installation: torch 2.0.0+cu118
#     Uninstalling torch-2.0.0+cu118:
#       Successfully uninstalled torch-2.0.0+cu118
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.15.1+cu118
#     Uninstalling torchvision-0.15.1+cu118:
#       Successfully uninstalled torchvision-0.15.1+cu118
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchtext 0.15.1 requires torch==2.0.0, but you have torch 1.7.1+cu110 which is incompatible.
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %pip install click requests tqdm pyspng ninja imageio-ffmpeg==0.4.3
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 206.5/206.5 kB 17.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 146.0/146.0 kB 18.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.9/26.9 MB 53.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: imageio-ffmpeg
#     Found existing installation: imageio-ffmpeg 0.4.8
#     Uninstalling imageio-ffmpeg-0.4.8:
#       Successfully uninstalled imageio-ffmpeg-0.4.8
# ...

# %%
# !python dataset_tool.py --help
# Out:
# Usage: dataset_tool.py [OPTIONS]
#
#   Convert an image dataset into a dataset archive
#   usable with StyleGAN2 ADA PyTorch.
#
#   The input dataset format is guessed from the
#   --source argument:
#
#   --source *_lmdb/                    Load LSUN dataset
#   --source cifar-10-python.tar.gz     Load CIFAR-10 dataset
#   --source train-images-idx3-ubyte.gz Load MNIST dataset
#   --source path/                      Recursively load all images from path/
#   --source dataset.zip                Recursively load all images from dataset.zip
#
#   Specifying the output format and path:
#
#   --dest /path/to/dir                 Save output files under /path/to/dir
#   --dest /path/to/dataset.zip         Save output files into /path/to/dataset.zip
#
#   The output dataset format can be either an image
#   folder or an uncompressed zip archive. Zip
#   archives makes it easier to move datasets around
#   file servers and clusters, and may offer better
# ...

# %%
# !python covert_to.py

# %%
# !python dataset_tool.py --source=/content/drive/MyDrive/disgust_rgb --dest=/content/dataset.zip --width=128 --height=128
# Out:
# 100% 431/431 [00:01<00:00, 307.02it/s]

# %%
# !python train.py --outdir=/content/training-runs --data=/content/dataset.zip --resume='ffhq256' --kimg=20
# Out:
# Training options:
# {
#   "num_gpus": 1,
#   "image_snapshot_ticks": 50,
#   "network_snapshot_ticks": 50,
#   "metrics": [
#     "fid50k_full"
#   ],
#   "random_seed": 0,
#   "training_set_kwargs": {
#     "class_name": "training.dataset.ImageFolderDataset",
#     "path": "/content/dataset.zip",
#     "use_labels": false,
#     "max_size": 431,
#     "xflip": false,
#     "resolution": 128
#   },
#   "data_loader_kwargs": {
#     "pin_memory": true,
#     "num_workers": 3,
#     "prefetch_factor": 2
#   },
#   "G_kwargs": {
#     "class_name": "training.networks.Generator",
#     "z_dim": 512,
#     "w_dim": 512,
#     "mapping_kwargs": {
#       "num_layers": 2
#     },
#     "synthesis_kwargs": {
#       "channel_base": 16384,
#       "channel_max": 512,
#       "num_fp16_res": 4,
#       "conv_clamp": 256
#     }
#   },
#   "D_kwargs": {
#     "class_name": "training.networks.Discriminator",
#     "block_kwargs": {},
#     "mapping_kwargs": {},
#     "epilogue_kwargs": {
# ...

# %%
# !python generate.py --outdir=/content/out --trunc=1 --network=/content/training-runs/00004-dataset-auto1-kimg20-resumeffhq256/network-snapshot-000020.pkl --seeds=0-3999
# Out:
# Loading networks from "/content/training-runs/00004-dataset-auto1-kimg20-resumeffhq256/network-snapshot-000020.pkl"...
# Generating image for seed 0 (0/4000) ...
# Setting up PyTorch plugin "bias_act_plugin"... Done.
# Setting up PyTorch plugin "upfirdn2d_plugin"... Done.
# Generating image for seed 1 (1/4000) ...
# Generating image for seed 2 (2/4000) ...
# Generating image for seed 3 (3/4000) ...
# Generating image for seed 4 (4/4000) ...
# Generating image for seed 5 (5/4000) ...
# Generating image for seed 6 (6/4000) ...
# Generating image for seed 7 (7/4000) ...
# Generating image for seed 8 (8/4000) ...
# Generating image for seed 9 (9/4000) ...
# Generating image for seed 10 (10/4000) ...
# Generating image for seed 11 (11/4000) ...
# Generating image for seed 12 (12/4000) ...
# Generating image for seed 13 (13/4000) ...
# Generating image for seed 14 (14/4000) ...
# Generating image for seed 15 (15/4000) ...
# Generating image for seed 16 (16/4000) ...
# ...

# %%
# !python generate.py --outdir=/content/out --trunc=1 --seeds=85,265,297,849 \
    --network=/content/training-runs/00000-dataset-auto1-kimg10/network-snapshot-000010.pkl
# Out:
# Loading networks from "/content/training-runs/00000-dataset-auto1-kimg10/network-snapshot-000010.pkl"...
# Generating image for seed 85 (0/4) ...
# Setting up PyTorch plugin "bias_act_plugin"... Done.
# Setting up PyTorch plugin "upfirdn2d_plugin"... Done.
# Traceback (most recent call last):
#   File "/content/stylegan2-ada-pytorch/generate.py", line 127, in <module>
#     generate_images() # pylint: disable=no-value-for-parameter
#   File "/usr/local/lib/python3.9/dist-packages/click/core.py", line 1130, in __call__
#     return self.main(*args, **kwargs)
#   File "/usr/local/lib/python3.9/dist-packages/click/core.py", line 1055, in main
#     rv = self.invoke(ctx)
#   File "/usr/local/lib/python3.9/dist-packages/click/core.py", line 1404, in invoke
#     return ctx.invoke(self.callback, **ctx.params)
#   File "/usr/local/lib/python3.9/dist-packages/click/core.py", line 760, in invoke
#     return __callback(*args, **kwargs)
# ...

# %%
# !zip -r /content/out.zip /content/out
# Out:
#   adding: content/out/ (stored 0%)
#   adding: content/out/seed1561.png (stored 0%)
#   adding: content/out/seed0884.png (stored 0%)
#   adding: content/out/seed0059.png (deflated 0%)
#   adding: content/out/seed0644.png (stored 0%)
#   adding: content/out/seed0159.png (deflated 0%)
#   adding: content/out/seed3119.png (stored 0%)
#   adding: content/out/seed1932.png (stored 0%)
#   adding: content/out/seed0608.png (deflated 0%)
#   adding: content/out/seed1123.png (deflated 0%)
#   adding: content/out/seed2762.png (deflated 0%)
#   adding: content/out/seed3629.png (deflated 0%)
#   adding: content/out/seed0985.png (deflated 0%)
#   adding: content/out/seed1474.png (stored 0%)
#   adding: content/out/seed3594.png (deflated 0%)
#   adding: content/out/seed2964.png (deflated 0%)
#   adding: content/out/seed1479.png (deflated 0%)
#   adding: content/out/seed3413.png (deflated 0%)
#   adding: content/out/seed2493.png (deflated 0%)
#   adding: content/out/seed3947.png (stored 0%)
# ...

# %%
generate.py --help
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-31dd76c196e4> in <cell line: 1>()
# ----> 1 generate.py --help
#
# NameError: name 'generate' is not defined
